# %% [markdown]
# <a href="https://colab.research.google.com/github/renatamontanhana/Machine_Learning_Algoritmo_Naive_Bayes_CDPRO/blob/main/M4_Manipulando_Arquivos_Diversos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# # <font color='BLUE'>Cientista de Dados na Prática </font>
#
# # <font color='GREEN'>Módulo 4 - Análise Exploratória dos Dados</font>
#
# # <font color='GREY'> Manipulando Arquivos Diversos </font>

# %% [markdown]
# # 1° Lendo arquivos de Imagens

# %%
# Imagem
from PIL import Image
# %matplotlib inline
img = Image.open("/content/pb.jpg")
img.show()
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %% [markdown]
# # 2° Lendo arquivos de Vídeo indexados na WEB

# %%
#Vídeo
from IPython.core.display import HTML

HTML('<iframe width="380" height="200" src="https://www.youtube.com/embed/c4wDGK9eUyc" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="380" height="200" src="https://www.youtube.com/embed/c4wDGK9eUyc" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # 3° Manipulando arquivo ZIP

# %%
# Arquivo Zip
from zipfile import ZipFile

# path to the zipfile
file = '/content/Inscritos_P__s_LS.zip'

# read zipfile and extract contents
with ZipFile (file, 'r') as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# Inscritos_P__s_LS.csv                          2020-10-09 08:28:10         7028

# %% [markdown]
# ## 4° Manipulando arquivos separados por vírgula CSV

# %%
#Arquivo CSV
import pandas as pd
df = pd.read_csv('/content/Inscritos_P__s_LS.csv')
df
# Out:
#                                 email
# 0    tadeuconsultorsistemas@gmail.com
# 1                 ednammv@hotmail.com
# 2               joaogui21@hotmail.com
# 3            hudsonsouzask8@gmail.com
# 4           antoniomarcop@hotmail.com
# ..                                ...
# 251              alex.nasc@uol.com.br
# 252        viniciusdereck39@gmail.com
# 253             matheus1782@gmail.com
# 254    larissa.dias.souza@hotmail.com
# 255       analuazevedogomes@gmail.com
#
# [256 rows x 1 columns]

# %% [markdown]
# ## 5° Manipulando arquivos em texto TXT

# %%
# Arquivo TXT
with open(r'/content/arquivo_texto.txt','r') as arquivo:
    print(arquivo.read())

# %% [markdown]
# # 6° Manipulando arquivos Excel

# %%
# Arquivo Excel
df = pd.read_excel(r'/content/Cronograma do CDP.xlsx')
# print values
df

# %%
# Lendo as sheets do Excel
xl = pd.ExcelFile(r'/content/Cronograma do CDP.xlsx')

# print sheet name
xl.sheet_names
# Out:
# ['Interno', 'Aluno']

# %%
# Abrindo a sheets específica
df = pd.read_excel(r'/content/Cronograma do CDP.xlsx', sheet_name='Aluno')
df
# Out:
#   CIENTISTA DE DADOS NA PRÁTICA                Unnamed: 1
# 0                       Módulos  Data da Disponibilização
# 1                      Módulo 1           Disponibilizado
# 2                      Módulo 2           Disponibilizado
# 3                      Módulo 3       2020-10-01 00:00:00
# 4                      Módulo 4       2020-10-08 00:00:00
# 5                      Módulo 5       2020-10-15 00:00:00
# 6                      Módulo 6       2020-10-22 00:00:00
# 7                      Módulo 7       2020-10-29 00:00:00
# 8                         Bônus       2020-11-05 00:00:00

# %% [markdown]
# # 7° Manipulando arquivos em Banco de Dados SQLite

# %%
# Acessando dados do Banco de Dados
import pandas as pd
import sqlite3

# open engine connection
con= sqlite3.connect('/content/escola.db')

# create a cursor object
cur = con.cursor()

# %%
# Criar uma Consulta: Query
Query = cur.execute('select * from cursos')

# %%
# Save results of the query to DataFrame: df
df = pd.DataFrame(Query.fetchall(), columns=['ID','NM','LABEL'])

# Close connection
con.commit()

# Print head of DataFrame df
df

# %% [markdown]
# ## 8° Manipulando arquivos JSON

# %%
# manipulando arquivos JSON
import json

# open json file
with open('/content/JSON','r') as file:
    data = json.load(file)

# %%
# json dictionary
print(type(data))
# Out:
# <class 'list'>

# %%
# Transformando em DataFrame
df_json = pd.DataFrame(data)
df_json

# %%
# Lendo o JSON diretamente do PANDAS
arquivo = '/content/JSON'
df = pd.read_json(arquivo)
df

# %% [markdown]
# # Fim

# %% [markdown]
# ## Valeu!

# %% [markdown]
# ### #Facebook - Ciencia dos Dados <a href="http://facebook.com/cienciadosdadosbr">facebook.com/cienciadosdadosbr</a>
